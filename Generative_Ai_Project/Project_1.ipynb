# %%
### Langchain Version

# %%
import langchain
print(langchain.__version__)
# Out:
# 1.2.13

# %%
import os 
from dotenv import load_dotenv
load_dotenv()
os.environ["GOOGLE_API_KEY"] = "AIzaSyDFGrBLRCl7brf2Kh0YPE6pF_koxnGnb0w"
print(os.getenv("GOOGLE_API_KEY"))
# Out:
# AIzaSyDFGrBLRCl7brf2Kh0YPE6pF_koxnGnb0w

# %%
##---- Using Gemini 2.5 Flash Lite Model---
from langchain.chat_models import init_chat_model
chat_model = init_chat_model("google_genai:gemini-2.5-flash-lite")
response = chat_model.invoke("What is the capital of France?")  
print(response.content)
# Out:
# The capital of France is **Paris**.
